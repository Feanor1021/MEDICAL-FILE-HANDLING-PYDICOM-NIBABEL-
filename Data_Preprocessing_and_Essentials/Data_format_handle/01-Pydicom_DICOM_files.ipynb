# %% [markdown]
# ## DICOM FILE HANDLING

# %% [markdown]
# First we import the necessary libraries and set the path to the directory containing the DICOM files

# %% [markdown]
# ## Imports
# * pathlib for easy path handling
# * pydicom to handle dicom files
# * matplotlib for visualization
# * numpy to create the 3D container

# %%
from pathlib import Path
import pydicom
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# At first we try to read a single dcm file <br />
# To this end we use the **read_file(path)** function provided by pydicom

# %%
dcm_file = pydicom.read_file("ID_0000_AGE_0060_CONTRAST_1_CT.dcm")

# %% [markdown]
# Let's take a look what this file contains. <br />
# You can *print* the dicom file to get a bulk of information, containing e.g the company which built the scanner (SIEMENS in this case), the shape of the image (*Rows, Columns*, 512x512 in this case), table height all information about the patient (of course the personal information is anonymized here), and of large importance, the **image orientation**
#
# Feel free to scroll through the available information

# %%
print(dcm_file)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 194
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.7777.9002.108821836759549281694712274169
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.31'
# -------------------------------------------------
# (0008, 0000) Group Length                        UL: 430
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.7777.9002.108821836759549281694712274169
# (0008, 0020) Study Date                          DA: '19830708'
# (0008, 0021) Series Date                         DA: '19830708'
# (0008, 0022) Acquisition Date                    DA: '19830708'
# (0008, 0023) Content Date                        DA: '19830708'
# (0008, 0030) Study Time                          TM: '085723.000000'
# (0008, 0031) Series Time                         TM: '090344.332000'
# (0008, 0032) Acquisition Time                    TM: '090517.558000'
# (0008, 0033) Content Time                        TM: '090501.593000'
# (0008, 0040) Data Set Type                       US: 0
# (0008, 0041) Data Set Subtype                    LO: 'IMA SPI'
# (0008, 0050) Accession Number                    SH: '2819497684894126'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'SOMATOM PLUS 4'
# (0008, 2111) Derivation Description              ST: ''
# (0009, 0000) Private Creator                     UN: b'\x86\x00\x00\x00'
# (0009, 0010) Private tag data                    LO: 'SPI RELEASE 1'
# (0009, 0012) Private tag data                    LO: 'SIEMENS CM VA0  CMS'
# (0009, 0013) Private tag data                    LO: 'SIEMENS CM VA0  LAB'
# (0009, 0020) Private tag data                    LO: 'SIEMENS CT VA0  IDE'
# (0009, 0030) Private tag data                    LO: 'SIEMENS CT VA0  ORI'
# (0010, 0000) Group Length                        UL: 70
# (0010, 0010) Patient's Name                      PN: 'TCGA-17-Z034'
# (0010, 0020) Patient ID                          LO: 'TCGA-17-Z034'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '060Y'
# (0011, 0000) Private Creator                     UN: b'F\x00\x00\x00'
# (0011, 0010) Private tag data                    LO: 'SPI RELEASE 1'
# (0011, 0011) Private tag data                    LO: 'SIEMENS CM VA0  CMS'
# (0011, 0012) Private tag data                    LO: 'SIEMENS ISI'
# (0012, 0000) Group Length                        UL: 758
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: 'Per DICOM PS 3.15 AnnexE. Details in 0012,0064'
# (0012, 0064)  De-identification Method Code Sequence  8 item(s) ----
#    (0008, 0000) Group Length                        UL: 76
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0000) Group Length                        UL: 58
#    (0008, 0100) Code Value                          SH: '113101'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Pixel Data Option'
#    ---------
#    (0008, 0000) Group Length                        UL: 56
#    (0008, 0100) Code Value                          SH: '113103'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Graphics Option'
#    ---------
#    (0008, 0000) Group Length                        UL: 58
#    (0008, 0100) Code Value                          SH: '113105'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Descriptors Option'
#    ---------
#    (0008, 0000) Group Length                        UL: 80
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal With Modified Dates Option'
#    ---------
#    (0008, 0000) Group Length                        UL: 72
#    (0008, 0100) Code Value                          SH: '113108'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#    ---------
#    (0008, 0000) Group Length                        UL: 64
#    (0008, 0100) Code Value                          SH: '113109'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Device Identity Option'
#    ---------
#    (0008, 0000) Group Length                        UL: 60
#    (0008, 0100) Code Value                          SH: '113111'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
# (0013, 0000) Private Creator                     UN: b'.\x00\x00\x00'
# (0013, 0010) Private tag data                    LO: 'CTP'
# (0013, 1010) Private tag data                    UN: b'TCGA-LUAD\x00'
# (0013, 1013) Private tag data                    UN: b'77779002'
# (0018, 0000) Group Length                        UL: 342
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 0020) Scanning Sequence                   CS: 'RM'
# (0018, 0050) Slice Thickness                     DS: '8.0'
# (0018, 0060) KVP                                 DS: '140.0'
# (0018, 0090) Data Collection Diameter            DS: '500.0'
# (0018, 1000) Device Serial Number                LO: '                     20643'
# (0018, 1020) Software Versions                   LO: 'VB40W'
# (0018, 1110) Distance Source to Detector         DS: '1005.0'
# (0018, 1111) Distance Source to Patient          DS: '570.0'
# (0018, 1120) Gantry/Detector Tilt                DS: '0.0'
# (0018, 1130) Table Height                        DS: '170.0'
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '750'
# (0018, 1151) X-Ray Tube Current                  IS: '206'
# (0018, 1152) Exposure                            IS: '155'
# (0018, 1170) Generator Power                     IS: '29'
# (0018, 1190) Focal Spot(s)                       DS: '1.2'
# (0018, 1200) Date of Last Calibration            DA: '19830623'
# (0018, 1201) Time of Last Calibration            TM: '214703.931000'
# (0018, 1210) Convolution Kernel                  SH: '59 .10.AB50'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0019, 0000) Private Creator                     UN: b'\xf4\x00\x00\x00'
# (0019, 0010) Private tag data                    LO: 'SIEMENS CM VA0  CMS'
# (0019, 0011) Private tag data                    LO: 'SIEMENS CT VA0  GEN'
# (0019, 0013) Private tag data                    LO: 'SIEMENS CT VA0  COAD'
# (0019, 0015) Private tag data                    LO: 'SIEMENS CM VA0  ACQU'
# (0019, 1392) [Osteo Regression Line Slope]       DS: '0.979'
# (0019, 1393) [Osteo Regression Line Intercept]   DS: '-1.42'
# (0019, 13b0) [Feed per Rotation]                 DS: '8.0'
# (0019, 13c0) [Pulmo Water]                       DS: '2.154907'
# (0019, 13c1) [Pulmo Air]                         DS: '-992.9709'
# (0019, 13c3) [Pulmo Time]                        TM: '201523.000000'
# (0020, 0000) Group Length                        UL: 566
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.7777.9002.292315456232117737481743327260
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.7777.9002.531955806841803044139009743992
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '5'
# (0020, 0012) Acquisition Number                  IS: '3'
# (0020, 0013) Instance Number                     IS: '25'
# (0020, 0030) Image Position                      DS: [-02.166094E+02, -2.086094E+02, -2.475000E+02]
# (0020, 0032) Image Position (Patient)            DS: [-217, -209, -247.5]
# (0020, 0035) Image Orientation                   DS: [001.000000E+00, 00.000000E+00, 00.000000E+00, 00.000000E+00, 01.000000E+00, 00.000000E+00]
# (0020, 0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, 0]
# (0020, 0050) Location                            DS: '-247.5'
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.7777.9002.299172824841582204484171666104
# (0020, 0070) Image Geometry Type                 LO: 'PLANAR'
# (0020, 0080) Masking Image                       CS: ''
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: '-247.5'
# (0020, 3100) Source Image IDs                    CS: ''
# (0020, 3402) Modified Image ID                   CS: ''
# (0020, 3403) Modified Image Date                 DA: ''
# (0020, 3405) Modified Image Time                 TM: ''
# (0020, 5000) Original Image Identification       AT: None
# (0020, 5002) Original Image Identification Nomen LO: ''
# (0021, 0000) Private Creator                     UN: b'h\x00\x00\x00'
# (0021, 0010) Private tag data                    LO: 'SIEMENS MED'
# (0021, 0012) Private tag data                    LO: 'SIEMENS CT VA0  GEN'
# (0021, 0022) Private tag data                    LO: 'SIEMENS CT VA0  RAW'
# (0021, 0030) Private tag data                    LO: 'SIEMENS CT VA0  ORMR'
# (0028, 0000) Group Length                        UL: 290
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0005) Image Dimensions                    US: 2
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [007.812500e-01, 007.812500e-01]
# (0028, 0040) Image Format                        CS: 'RECT'
# (0028, 0050) Manipulated Image                   LO: ''
# (0028, 0060) Compression Code                    CS: 'NONE'
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0200) Image Location                      US: 32736
# (0028, 0301) Burned In Annotation                CS: 'NO'
# (0028, 0303) Longitudinal Temporal Information M CS: 'MODIFIED'
# (0028, 1050) Window Center                       DS: [000010, -0550]
# (0028, 1051) Window Width                        DS: [000400, 01800]
# (0028, 1052) Rescale Intercept                   DS: '-1024.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0029, 0000) Private Creator                     UN: b'N\x00\x00\x00'
# (0029, 0010) Private tag data                    LO: 'SIEMENS MED DISPLAY'
# (0029, 0011) Private tag data                    LO: 'SIEMENS CM VA0  CMS'
# (0029, 0030) Private tag data                    LO: 'SIEMENS MED MG'
# (0031, 0000) Private Creator                     UN: b'\x14\x00\x00\x00'
# (0031, 0012) Private tag data                    LO: 'SIEMENS ISI'
# (0032, 0000) Group Length                        UL: 8
# (0032, 4000) Study Comments                      LT: ''
# (0040, 0000) Group Length                        UL: 8
# (0040, 1003) Requested Procedure Priority        SH: ''
# (0091, 0000) Private Creator                     UN: b'\x0e\x00\x00\x00'
# (0091, 0010) Private tag data                    LO: 'SIENET'
# (0095, 0000) Private Creator                     UN: b'\x0e\x00\x00\x00'
# (0095, 0010) Private tag data                    LO: 'SIENET'
# (0097, 0000) Private Creator                     UN: b'\x0e\x00\x00\x00'
# (0097, 0010) Private tag data                    LO: 'SIENET'
# (0099, 0000) Private Creator                     UN: b'\x0e\x00\x00\x00'
# (0099, 0010) Private tag data                    LO: 'SIENET'
# (7003, 0000) Private Creator                     UN: b'\x14\x00\x00\x00'
# (7003, 0010) Private tag data                    LO: 'SIEMENS MED'
# (7fe0, 0000) Group Length                        UL: 524296
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements

# %% [markdown]
# Accessing DICOM **header** information:
# You can access the dicom tags by using the hexadecimal encoded identifiers at the start of each line.
# As an example, if you want to get the shape of the image you can use those two identifiers
#
# * (0028, 0010) Rows
# * (0028, 0011) Columns
# * (0018, 0015) Body Part Examined
#
# The 0x in front of the identifier tells the python interpreter that it should interpret this value as hexadecimal

# %%
dcm_file[0x0010, 0x0010]
# Out:
# (0010, 0010) Patient's Name                      PN: 'TCGA-17-Z034'

# %% [markdown]
# There is an alternative, more direct way to access the values of the DICOM header tags using the tag descriptions
#     <br /> Please note the lettering: 'Body Part Examined' becomes 'BodyPartExamined' (so-called Pascal Case):

# %%
dcm_file.Rows
# Out:
# 512

# %% [markdown]
# Accessing DICOM **body** information (the actual image):
#
# The **pixel_array** contains the actual image data:

# %%
ct = dcm_file.pixel_array
plt.figure()
plt.imshow(ct, cmap="bone")

# %% [markdown]
# We can perform a quick sanity check and make sure that the image shape corresponds to the Rows and Columns we saw earlier in the header information (512x512)

# %%
print(ct.shape)
# Out:
# (512, 512)

# %% [markdown]
# ## 3D Data

# %%
path_to_head_mri = Path("SE000001/") # why ?

# %% [markdown]
# We can use the glob function to return all items in a directory which correspond to the provided pattern. <br />
# 1As in this case, the directory only contains the DICOM files, we can return all files in it ("*")

# %%
all_files = list(path_to_head_mri.glob("*")) # wildcard

# %% [markdown]
# It crucial to order them, as otherwise your complete scan would be shuffeled and useless
#
# We can use the "SliceLocation" attribute passed to the *sorted* function to identify the 2D slice position and thus order the slices

# %%
all_files.sort() # dicom file slices should be ordered !!! thats crucial
all_files
# Out:
# [WindowsPath('SE000001/MR000000'),
#  WindowsPath('SE000001/MR000001'),
#  WindowsPath('SE000001/MR000002'),
#  WindowsPath('SE000001/MR000003'),
#  WindowsPath('SE000001/MR000004'),
#  WindowsPath('SE000001/MR000005'),
#  WindowsPath('SE000001/MR000006'),
#  WindowsPath('SE000001/MR000007'),
#  WindowsPath('SE000001/MR000008'),
#  WindowsPath('SE000001/MR000009'),
#  WindowsPath('SE000001/MR000010'),
#  WindowsPath('SE000001/MR000011'),
#  WindowsPath('SE000001/MR000012'),
#  WindowsPath('SE000001/MR000013'),
#  WindowsPath('SE000001/MR000014'),
#  WindowsPath('SE000001/MR000015'),
#  WindowsPath('SE000001/MR000016'),
#  WindowsPath('SE000001/MR000017'),
#  WindowsPath('SE000001/MR000018'),
#  WindowsPath('SE000001/MR000019'),
#  WindowsPath('SE000001/MR000020'),
#  WindowsPath('SE000001/MR000021'),
#  WindowsPath('SE000001/MR000022'),
#  WindowsPath('SE000001/MR000023'),
#  WindowsPath('SE000001/MR000024'),
#  WindowsPath('SE000001/MR000025'),
#  WindowsPath('SE000001/MR000026')]

# %% [markdown]
# Now we will read these files by using the read_file method and append them to a list

# %%
mri_datas = []

for path in all_files:
    mri_datas.append(pydicom.read_file(path))

# %%
mri_datas[3] # you have all slices in this var lets prints the 4th slice
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 214
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.46.670589.11.0.0.11.4.2.0.12098.5.4500.2015011413272264724
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.840.114089.1.0.0.3.3.38
# (0002, 0013) Implementation Version Name         SH: 'DCF 3.3.38c'
# (0002, 0016) Source Application Entity Title     AE: 'DCF'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
# (0008, 0012) Instance Creation Date              DA: '20150114'
# (0008, 0013) Instance Creation Time              TM: '132938'
# (0008, 0014) Instance Creator UID                UI: 1.3.46.670589.11.12098.5
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.46.670589.11.0.0.11.4.2.0.12098.5.4500.2015011413272264724
# (0008, 0020) Study Date                          DA: '20150114'
# (0008, 0021) Series Date                         DA: '20150114'
# (0008, 0022) Acquisition Date                    DA: '20150114'
# (0008, 0023) Content Date                        DA: '20150114'
# (0008, 0030) Study Time                          TM: '132242'
# (0008, 0031) Series Time                         TM: '132628.00000'
# (0008, 0032) Acquisition Time                    TM: '132628.00'
# (0008, 0033) Content Time                        TM: '132628.00'
# (0008, 0050) Accession Number                    SH: 'RJN78893652'
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'Philips Medical Systems'
# (0008, 0080) Institution Name                    LO: 'Macclesfield'
# (0008, 0090) Referring Physician's Name          PN: 'WHITTINGHAM VM^-'
# (0008, 1010) Station Name                        SH: 'PMSN-X6FNOVG0RR'
# (0008, 1030) Study Description                   LO: 'MRI Head'
# (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'MSKUH'
#    (0008, 0102) Coding Scheme Designator            SH: 'BROKER'
#    (0008, 0104) Code Meaning                        LO: 'MRI Head'
#    ---------
# (0008, 103e) Series Description                  LO: 'T2W_TSE'
# (0008, 1040) Institutional Department Name       LO: 'MRI'
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Achieva'
# (0008, 1111)  Referenced Performed Procedure Step Sequence  1 item(s) ----
#    (0008, 0012) Instance Creation Date              DA: '20150114'
#    (0008, 0013) Instance Creation Time              TM: '132938'
#    (0008, 0014) Instance Creator UID                UI: 1.3.46.670589.11.12098.5
#    (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.46.670589.11.0.0.11.4.2.0.12098.5.6788.2015011413224231041
#    (0020, 0013) Instance Number                     IS: '0'
#    (2005, 0014) Private Creator                     LO: 'Philips MR Imaging DD 005'
#    (2005, 1406) [Unknown]                           SS: 0
#    ---------
# (0008, 1140)  Referenced Image Sequence  3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.46.670589.11.0.0.11.4.2.0.12098.5.4500.2015011413255028693
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.46.670589.11.0.0.11.4.2.0.12098.5.4500.2015011413255023690
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.46.670589.11.0.0.11.4.2.0.12098.5.4500.2015011413255025691
#    ---------
# (0009, 0000) Private Creator                     UL: 14
# (0009, 0010) Private tag data                    LO: 'GEIIS'
# (0010, 0010) Patient's Name                      PN: 'LIONHEART^WILLIAM'
# (0010, 0020) Patient ID                          LO: 'RJN7270540X'
# (0010, 0021) Issuer of Patient ID                LO: 'RJN'
# (0010, 0030) Patient's Birth Date                DA: '19620726'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1000) Other Patient IDs                   LO: '4824124506'
# (0010, 1030) Patient's Weight                    DS: '82.0'
# (0010, 1040) Patient's Address                   LO: 'MARSHAM, START LANE, WHALEY BRIDGE, SK23 7BP'
# (0010, 21c0) Pregnancy Status                    US: 4
# (0018, 0015) Body Part Examined                  CS: 'HEAD'
# (0018, 0020) Scanning Sequence                   CS: 'SE'
# (0018, 0021) Sequence Variant                    CS: 'SK'
# (0018, 0022) Scan Options                        CS: ''
# (0018, 0023) MR Acquisition Type                 CS: ''
# (0018, 0024) Sequence Name                       SH: ''
# (0018, 0050) Slice Thickness                     DS: '5.0'
# (0018, 0080) Repetition Time                     DS: '3136.03076171875'
# (0018, 0081) Echo Time                           DS: '110.0'
# (0018, 0083) Number of Averages                  DS: '1.0'
# (0018, 0084) Imaging Frequency                   DS: '63.895818'
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: '1'
# (0018, 0087) Magnetic Field Strength             DS: '1.5'
# (0018, 0088) Spacing Between Slices              DS: '6.0'
# (0018, 0089) Number of Phase Encoding Steps      IS: '173'
# (0018, 0091) Echo Train Length                   IS: '23'
# (0018, 0093) Percent Sampling                    DS: '75.0'
# (0018, 0094) Percent Phase Field of View         DS: '79.6875'
# (0018, 1000) Device Serial Number                LO: '12098'
# (0018, 1020) Software Versions                   LO: ['1.5.4', '1.5.4.9', 'Gyroscan PMS/DICOM 2.0 MR $Id: datadefs,v 5.27 2004/10/18 06:50:', 'Gyroscan PMS/DICOM 2.0 MR $Id: datadefs,v 5.27 2004/10/18 06:50:', 'Gyroscan PMS/DICOM 2.0 MR $Id: datadefs,v 5.27 2004/10/18 06:50:']
# (0018, 1030) Protocol Name                       LO: 'T2W_TSE'
# (0018, 1081) Low R-R Value                       IS: '0'
# (0018, 1082) High R-R Value                      IS: '0'
# (0018, 1083) Intervals Acquired                  IS: '0'
# (0018, 1084) Intervals Rejected                  IS: '0'
# (0018, 1088) Heart Rate                          IS: '0'
# (0018, 1100) Reconstruction Diameter             DS: '240.0'
# (0018, 1250) Receive Coil Name                   SH: 'Head'
# (0018, 1251) Transmit Coil Name                  SH: 'B'
# (0018, 1310) Acquisition Matrix                  US: [0, 256, 173, 0]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
# (0018, 1314) Flip Angle                          DS: '90.0'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.2.840.113619.2.243.6074146108103184.41976.4343.2084088
# (0020, 000e) Series Instance UID                 UI: 1.3.46.670589.11.0.0.11.4.2.0.12098.5.4500.2015011413262801702
# (0020, 0010) Study ID                            SH: '474297762'
# (0020, 0011) Series Number                       IS: '201'
# (0020, 0012) Acquisition Number                  IS: '2'
# (0020, 0013) Instance Number                     IS: '4'
# (0020, 0032) Image Position (Patient)            DS: [-123.63681343197, -136.82322192192, -31.449311554431]
# (0020, 0037) Image Orientation (Patient)         DS: [0.99935883283615, -0.0323828160762, 0.01527170091867, 0.03418818861246, 0.98977828025817, -0.1384561806917]
# (0020, 0052) Frame of Reference UID              UI: 1.3.46.670589.11.0.0.11.4.2.0.12098.5.5544.2015011413251448000
# (0020, 0100) Temporal Position Identifier        IS: '1'
# (0020, 0105) Number of Temporal Positions        IS: '1'
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: '17.9999979772582'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 256
# (0028, 0030) Pixel Spacing                       DS: [0.9375, 0.9375]
# (0028, 0034) Pixel Aspect Ratio                  IS: [1, 1]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1050) Window Center                       DS: '275.237242614144'
# (0028, 1051) Window Width                        DS: '478.563115487913'
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0032, 1032) Requesting Physician                PN: 'WHITTINGHAM VM^-'
# (0032, 1033) Requesting Service                  LO: 'Unspecified'
# (0032, 1060) Requested Procedure Description     LO: 'MRI Head'
# (0040, 0241) Performed Station AE Title          AE: 'RJN71PHMR01'
# (0040, 0244) Performed Procedure Step Start Date DA: '20150114'
# (0040, 0245) Performed Procedure Step Start Time TM: '132242'
# (0040, 0250) Performed Procedure Step End Date   DA: '20150114'
# (0040, 0251) Performed Procedure Step End Time   TM: '132242'
# (0040, 0253) Performed Procedure Step ID         SH: '474297762'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'MRI Head'
# (0040, 0260)  Performed Protocol Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'MSKUH'
#    (0008, 0102) Coding Scheme Designator            SH: 'BROKER'
#    (0008, 0104) Code Meaning                        LO: 'MRI Head'
#    (0008, 010b) Context Group Extension Flag        CS: 'N'
#    ---------
# (0040, 0275)  Request Attributes Sequence  1 item(s) ----
#    (0040, 1001) Requested Procedure ID              SH: 'RJN78893652'
#    ---------
# (0040, 0321)  Film Consumption Sequence  0 item(s) ----
# (0040, 2017) Filler Order Number / Imaging Servi LO: '77706562'
# (0903, 0010) Private Creator                     LO: 'GEIIS PACS'
# (0903, 1010) [Reject Image Flag]                 US: 0
# (0903, 1011) [Significant Flag]                  US: 0
# (0903, 1012) [Confidential Flag]                 US: 0
# (0905, 0010) Private Creator                     LO: 'GEIIS'
# (0905, 1030) [Assigning Authority For Patient ID LO: 'RJN'
# (2001, 0010) Private Creator                     LO: 'Philips Imaging DD 001'
# (2001, 0090) Private Creator                     LO: 'Philips Imaging DD 129'
# (2001, 1001) [Chemical Shift]                    FL: 0.0
# (2001, 1002) [Chemical Shift Number MR]          IS: '0'
# (2001, 1003) [Diffusion B-Factor]                FL: 0.0
# (2001, 1006) [Image Enhanced]                    CS: 'N'
# (2001, 1007) [Image Type ED ES]                  CS: 'U'
# (2001, 1008) [Phase Number]                      IS: '1'
# (2001, 1009) [Unknown]                           FL: 0.0
# (2001, 100a) [Slice Number MR]                   IS: '4'
# (2001, 100b) [Slice Orientation]                 CS: 'TRANSVERSAL'
# (2001, 100c) [Unknown]                           CS: 'N'
# (2001, 100e) [Unknown]                           CS: 'N'
# (2001, 100f) [Unknown]                           SS: 0
# (2001, 1010) [Cardiac Sync]                      CS: 'NO'
# (2001, 1011) [Diffusion Echo Time]               FL: 0.0
# (2001, 1012) [Dynamic Series]                    CS: 'N'
# (2001, 1013) [EPI Factor]                        SL: 1
# (2001, 1014) [Number of Echoes]                  SL: 1
# (2001, 1015) [Number of Locations]               SS: 1
# (2001, 1016) [Number of PC Directions]           SS: 0
# (2001, 1017) [Number of Phases MR]               SL: 1
# (2001, 1018) [Number of Slices MR]               SL: 27
# (2001, 1019) [Partial Matrix Scanned]            CS: 'N'
# (2001, 101a) [PC Velocity]                       FL: [0.0, 0.0, 0.0]
# (2001, 101b) [Prepulse Delay]                    FL: 0.0
# (2001, 101c) [Prepulse Type]                     CS: 'NO'
# (2001, 101d) [Reconstruction Number MR]          IS: '1'
# (2001, 101f) [Respiration Sync]                  CS: 'NO'
# (2001, 1020) [Scanning Technique Description MR] LO: 'TSE'
# (2001, 1021) [SPIR]                              CS: 'N'
# (2001, 1022) [Water Fat Shift]                   FL: 1.3013890981674194
# (2001, 1023) [Flip Angle Philips]                DS: '90.0'
# (2001, 1024) [Interactive]                       CS: 'N'
# (2001, 1025) [Echo Time Display MR]              SH: '110'
# (2001, 105f)  Private tag data  1 item(s) ----
#    (2001, 0010) Private Creator                     LO: 'Philips Imaging DD 001'
#    (2001, 102d) [Number of Stack Slices]            SS: 27
#    (2001, 1032) [Stack Radial Angle]                FL: 0.0
#    (2001, 1033) [Stack Radial Axis]                 CS: 'AP'
#    (2001, 1035) [Stack Slice Number]                SS: 1
#    (2001, 1036) [Stack Type]                        CS: 'PARALLEL'
#    (2005, 0010) Private Creator                     LO: 'Philips MR Imaging DD 001'
#    (2005, 0013) Private Creator                     LO: 'Philips MR Imaging DD 004'
#    (2005, 1071) [Unknown]                           FL: -0.6091800332069397
#    (2005, 1072) [Unknown]                           FL: -1.9593315124511719
#    (2005, 1073) [Unknown]                           FL: -7.9840474128723145
#    (2005, 1074) [Unknown]                           FL: 240.0
#    (2005, 1075) [Unknown]                           FL: 161.0
#    (2005, 1076) [Unknown]                           FL: 191.25
#    (2005, 1078) [Unknown]                           FL: -13.602395057678223
#    (2005, 1079) [Unknown]                           FL: 13.183597564697266
#    (2005, 107a) [Unknown]                           FL: -0.24909068644046783
#    (2005, 107b) [Unknown]                           CS: 'RL'
#    (2005, 107e) [Unknown]                           FL: 6.0
#    (2005, 1081) [Unknown]                           CS: 'FH'
#    (2005, 10a3) [Unknown]                           IS: '7'
#    (2005, 10a4) [Unknown]                           IS: '0'
#    (2005, 10a5) [Unknown]                           IS: '0'
#    (2005, 10a6) [Unknown]                           IS: '1'
#    (2005, 10a7) [Unknown]                           CS: 'DEFAULT'
#    (2005, 1390) [Unknown]                           CS: 'R_A'
#    ---------
# (2001, 1060) [Number of Stacks]                  SL: 1
# (2001, 1061) [Unknown]                           CS: 'N'
# (2001, 1062) [Unknown]                           CS: 'N'
# (2001, 1063) [Examination Source]                CS: 'ELSEWHERE'
# (2001, 106e) [Series Type]                       SH: 'MRSERIES'
# (2001, 107b) [Acquisition Number]                IS: '2'
# (2001, 1081) [Number of Dynamic Scans]           IS: '1'
# (2001, 1082) [Echo Train Length]                 IS: '0'
# (2001, 1083) [Imaging Frequency]                 DS: '63.895818'
# (2001, 1084) [Inversion Time]                    DS: '0.0'
# (2001, 1085) [Magnetic Field Strength]           DS: '1.5'
# (2001, 1086) [Unknown]                           IS: '0'
# (2001, 1087) [Imaged Nucleus]                    SH: '1H'
# (2001, 1088) [Number of Averages]                DS: '1.0'
# (2001, 1089) [Phase FOV Percent]                 DS: '0.0'
# (2001, 108a) [Sampling Percent]                  DS: '0.0'
# (2001, 108b) [Unknown]                           SH: 'B'
# (2001, 10c8) Private tag data                    LO: '*FAST BRAIN'
# (2001, 9000)  Private tag data  1 item(s) ----
#    (0008, 0012) Instance Creation Date              DA: '20150114'
#    (0008, 0013) Instance Creation Time              TM: '132938'
#    (0008, 0014) Instance Creator UID                UI: 1.3.46.670589.11.12098.5
#    (0008, 0016) SOP Class UID                       UI: Grayscale Softcopy Presentation State Storage
#    (0008, 0018) SOP Instance UID                    UI: 1.3.46.670589.11.0.0.51.4.3.0.12098.1.3104.1421242179343
#    (0008, 1115)  Referenced Series Sequence  1 item(s) ----
#       (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.46.670589.11.0.0.11.4.2.0.12098.5.4500.2015011413272264724
#          ---------
#       (0020, 000e) Series Instance UID                 UI: 1.3.46.670589.11.0.0.11.4.2.0.12098.5.4500.2015011413262801702
#       ---------
#    (0018, 1622) Shutter Presentation Value          US: 0
#    (0020, 0013) Instance Number                     IS: '1'
#    (0028, 3002) LUT Descriptor                      US: [0, 0, 0]
#    (0028, 3003) LUT Explanation                     LO: ''
#    (0028, 3006) LUT Data                            US: 0
#    (0028, 3110)  Softcopy VOI LUT Sequence  1 item(s) ----
#       (0028, 1050) Window Center                       DS: '976.0'
#       (0028, 1051) Window Width                        DS: '1697.0'
#       (2001, 0010) Private Creator                     LO: 'Philips Imaging DD 001'
#       (2001, 1053) [Window Invert]                     CS: 'N'
#       (2001, 1077) [GL TrafoType]                      CS: 'LINEARVOI'
#       ---------
#    (0070, 005a)  Displayed Area Selection Sequence  1 item(s) ----
#       (0070, 0052) Displayed Area Top Left Hand Corner SL: [1, 1]
#       (0070, 0053) Displayed Area Bottom Right Hand Co SL: [256, 256]
#       (0070, 0100) Presentation Size Mode              CS: 'SCALE TO FIT'
#       (0070, 0102) Presentation Pixel Aspect Ratio     IS: [1, 1]
#       (2001, 0010) Private Creator                     LO: 'Philips Imaging DD 001'
#       (2001, 103f) [Interpolation Method]              CS: 'BI_CUBIC'
#       ---------
#    (0070, 0080) Content Label                       CS: 'AS LAST SEEN'
#    (0070, 0081) Content Description                 LO: ''
#    (0070, 0082) Presentation Creation Date          DA: '20150114'
#    (0070, 0083) Presentation Creation Time          TM: '132727'
#    (0070, 0084) Content Creator's Name              PN: 'Achieva'
#    (2001, 0010) Private Creator                     LO: 'Philips Imaging DD 001'
#    (2001, 0090) Private Creator                     LO: 'Philips Imaging DD 129'
#    (2001, 1026) [Presentation State Subtraction Act CS: 'N'
#    (2001, 1067) [Unknown]                           CS: ''
#    (2001, 1068)  Private tag data  1 item(s) ----
#       (0028, 1052) Rescale Intercept                   DS: '0.0'
#       (0028, 1053) Rescale Slope                       DS: '3.54603174603175'
#       (0028, 1054) Rescale Type                        LO: 'normalized'
#       (2001, 0010) Private Creator                     LO: 'Philips Imaging DD 001'
#       (2001, 1077) [GL TrafoType]                      CS: 'LINEARMODALITY'
#       ---------
#    (2001, 1077) [GL TrafoType]                      CS: 'L_PRESENTATION'
#    (2001, 109f) [Pixel Processing Kernel Size]      US: [0, 0]
#    (2001, 9000)  Private tag data  0 item(s) ----
#    (2005, 0012) Private Creator                     LO: 'Philips MR Imaging DD 003'
#    (2005, 0013) Private Creator                     LO: 'Philips MR Imaging DD 004'
#    (2005, 0014) Private Creator                     LO: 'Philips MR Imaging DD 005'
#    (2005, 1234) [Unknown]                           SL: 0
#    (2005, 1257) [Unknown]                           SS: 0
#    (2005, 1281) [Unknown]                           UI: ''
#    (2005, 1282) [Unknown]                           CS: ''
#    (2005, 1389)  Private tag data  0 item(s) ----
#    (2005, 1406) [Unknown]                           SS: 0
#    (2050, 0020) Presentation LUT Shape              CS: 'IDENTITY'
#    ---------
# (2005, 0010) Private Creator                     LO: 'Philips MR Imaging DD 001'
# (2005, 0011) Private Creator                     LO: 'Philips MR Imaging DD 002'
# (2005, 0012) Private Creator                     LO: 'Philips MR Imaging DD 003'
# (2005, 0013) Private Creator                     LO: 'Philips MR Imaging DD 004'
# (2005, 0014) Private Creator                     LO: 'Philips MR Imaging DD 005'
# (2005, 1000) [Unknown]                           FL: -0.6091800332069397
# (2005, 1001) [Unknown]                           FL: -1.9593315124511719
# (2005, 1002) [Unknown]                           FL: -7.984046936035156
# (2005, 1004) [Unknown]                           CS: 'NONE'
# (2005, 1008) [Unknown]                           FL: -21.935766220092773
# (2005, 1009) [Unknown]                           FL: -46.231449127197266
# (2005, 100a) [Unknown]                           FL: 0.38882914185523987
# (2005, 100b) [Unknown]                           FL: 61574.50390625
# (2005, 100c) [Unknown]                           FL: 7.487471580505371
# (2005, 100d) [Unknown]                           FL: 0.0
# (2005, 100e) [Unknown]                           FL: 0.009394234046339989
# (2005, 100f) [Window Center]                     DS: '976.0'
# (2005, 1010) [Window Width]                      DS: '1697.0'
# (2005, 1011) [Unknown]                           CS: 'M'
# (2005, 1012) [Unknown]                           CS: 'N'
# (2005, 1013) [Unknown]                           CS: 'NO'
# (2005, 1014) [Unknown]                           CS: 'N'
# (2005, 1015) [Unknown]                           CS: 'N'
# (2005, 1016) [Unknown]                           CS: 'N'
# (2005, 1017) [Unknown]                           CS: 'N'
# (2005, 1019) [Unknown]                           CS: 'N'
# (2005, 101a) [Unknown]                           SS: 0
# (2005, 101b) [Unknown]                           CS: 'N'
# (2005, 101c) [Unknown]                           CS: 'N'
# (2005, 101d) [Unknown]                           SS: 256
# (2005, 101e) [Unknown]                           SH: 'compose'
# (2005, 101f) [Unknown]                           SH: 'compose'
# (2005, 1020) [Number of Chemical Shift]          SL: 0
# (2005, 1021) [Unknown]                           SS: 1
# (2005, 1022) [Unknown]                           IS: '0'
# (2005, 1023) [Unknown]                           SS: 0
# (2005, 1025) [Unknown]                           SS: 0
# (2005, 1026) [Unknown]                           CS: 'N'
# (2005, 1027) [Unknown]                           CS: 'MINIMUM'
# (2005, 1028) [Unknown]                           CS: 'N'
# (2005, 1029) [Unknown]                           CS: 'N'
# (2005, 102a) [Unknown]                           IS: '486048324'
# (2005, 102b) [Unknown]                           SS: 100
# (2005, 102c) [Unknown]                           CS: 'N'
# (2005, 102d) [Unknown]                           IS: '0'
# (2005, 102e) [Unknown]                           CS: 'N'
# (2005, 102f) [Unknown]                           CS: 'N'
# (2005, 1030) [Repetition Time]                   FL: 3136.03076171875
# (2005, 1031) [Unknown]                           CS: 'N'
# (2005, 1033) [Acquisition Duration]              FL: 43.9044303894043
# (2005, 1034) [Unknown]                           CS: 'Y'
# (2005, 1035) [Unknown]                           CS: 'PIXEL'
# (2005, 1036) [Unknown]                           CS: 'N'
# (2005, 1037) [Unknown]                           CS: 'N'
# (2005, 1038) [Unknown]                           CS: 'N'
# (2005, 1039) [Unknown]                           CS: 'N'
# (2005, 103b) [Unknown]                           CS: 'N'
# (2005, 103c) [Unknown]                           CS: 'N'
# (2005, 103d) [Unknown]                           SS: 102
# (2005, 103e) [Unknown]                           SL: Array of 102 elements
# (2005, 105f) [Unknown]                           CS: 'UNKNOWN'
# (2005, 1060) [Unknown]                           IS: '-1'
# (2005, 1061) [Unknown]                           CS: 'NO'
# (2005, 1063) [Unknown]                           SS: 0
# (2005, 106e) [Unknown]                           CS: 'SE'
# (2005, 106f) [Unknown]                           CS: 'MS'
# (2005, 1080)  Private tag data  0 item(s) ----
# (2005, 1083)  Private tag data  0 item(s) ----
# (2005, 1084)  Private tag data  0 item(s) ----
# (2005, 1085)  Private tag data  0 item(s) ----
# (2005, 1086) [Unknown]                           SS: 0
# (2005, 109e)  Private tag data  0 item(s) ----
# (2005, 10a0) [Unknown]                           FL: 0.0
# (2005, 10a2) [Unknown]                           CS: 'N'
# (2005, 10a8) [Unknown]                           DS: '0.0'
# (2005, 10a9) [Unknown]                           CS: 'NONE'
# (2005, 10b0) [Diffusion Direction RL]            FL: 0.0
# (2005, 10b1) [Diffusion Direction AP]            FL: 0.0
# (2005, 10b2) [Diffusion Direction FH]            FL: 0.0
# (2005, 10c0) [Unknown]                           CS: 'SE'
# (2005, 1199) [Unknown]                           UL: 1
# (2005, 1200) [Unknown]                           UL: 1
# (2005, 1201) [Unknown]                           UL: 0
# (2005, 1213) [Unknown]                           UL: 1
# (2005, 1245) [Unknown]                           SS: 2
# (2005, 1249) [Unknown]                           SS: 0
# (2005, 1251) [Unknown]                           SS: 0
# (2005, 1252) [Unknown]                           SS: 1
# (2005, 1253) [Unknown]                           SS: 1
# (2005, 1325) [Unknown]                           CS: 'N'
# (2005, 1326) [Unknown]                           FL: 0.0
# (2005, 1327) [Unknown]                           CS: 'REAL'
# (2005, 1328) [Unknown]                           CS: 'ORIGINAL'
# (2005, 1329) [Unknown]                           FL: 50.0
# (2005, 1330) [Unknown]                           CS: ['PLUS_A_PLUS_B', 'PLUS_A_PLUS_B', 'PLUS_A_PLUS_B', 'PLUS_A_PLUS_B']
# (2005, 1331) [Unknown]                           SS: 0
# (2005, 1333) [Unknown]                           FL: [0.0, 0.0, 0.0]
# (2005, 1334) [Unknown]                           CS: 'UNKNOWN'
# (2005, 1335) [Unknown]                           CS: 'UNKNOWN'
# (2005, 1336) [Unknown]                           FL: 0.0
# (2005, 1337) [Unknown]                           FL: 0.0
# (2005, 1338) [Unknown]                           FL: 0.0
# (2005, 1339) [Unknown]                           SS: [0, 0]
# (2005, 1340) [Unknown]                           CS: 'PRE_FT'
# (2005, 1341) [Unknown]                           CS: 'UNKNOWN'
# (2005, 1342) [Unknown]                           CS: 'FID'
# (2005, 1343) [Unknown]                           CS: 'Y'
# (2005, 1344) [Unknown]                           SS: Array of 40 elements
# (2005, 1345) [Unknown]                           CS: 'NO'
# (2005, 1346) [Unknown]                           CS: 'HERTZ'
# (2005, 1347) [Unknown]                           FL: 0.0
# (2005, 1348) [Unknown]                           CS: 'OFF'
# (2005, 1349) [Unknown]                           FL: 0.0
# (2005, 1350) [Unknown]                           FL: [0.0, 0.0]
# (2005, 1351) [Unknown]                           SS: 0
# (2005, 1352) [Unknown]                           SS: 0
# (2005, 1355) [Unknown]                           FL: Array of 30 elements
# (2005, 1356) [Unknown]                           CS: 'NO'
# (2005, 1357) [Unknown]                           SS: 0
# (2005, 1359) [Unknown]                           FL: 1.0
# (2005, 1360) [Unknown]                           FL: 0.0
# (2005, 1361) [Unknown]                           FL: [0.0, 0.0]
# (2005, 1362) [Unknown]                           FL: 0.0
# (2005, 1363) [Unknown]                           FL: 0.0
# (2005, 1364) [Unknown]                           CS: 'NO'
# (2005, 1370) [Unknown]                           SS: 0
# (2005, 1371)  Private tag data  0 item(s) ----
# (2005, 1381) [Unknown]                           IS: '3'
# (2005, 1382) [Unknown]                           UL: 1
# (2005, 1391) [Unknown]                           PN: ''
# (2005, 1392) [Unknown]                           IS: '0'
# (2005, 1393) [Unknown]                           IS: '-1'
# (2005, 1396) [Unknown]                           CS: 'NO'
# (2005, 1397) [Unknown]                           LO: 'SNM3.T-D1100.Head'
# (2005, 1398) [Unknown]                           CS: 'NO'
# (2005, 1399) [Unknown]                           CS: 'NO'
# (2005, 1400) [Unknown]                           CS: 'YES'
# (2005, 1401) [Unknown]                           UL: 1
# (2005, 1402)  Private tag data  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'MSKUH'
#    (0008, 0102) Coding Scheme Designator            SH: 'BROKER'
#    (0008, 0103) Coding Scheme Version               SH: ''
#    (0008, 0104) Code Meaning                        LO: 'MRI Head'
#    (0008, 010b) Context Group Extension Flag        CS: 'N'
#    (0008, 010d) Context Group Extension Creator UID UI: ''
#    ---------
# (2005, 1403) [Unknown]                           UL: 1
# (2005, 1406) [Unknown]                           SS: 0
# (2005, 1409) [Unknown]                           DS: '0.0'
# (2005, 140a) [Unknown]                           DS: '3.54603174603174'
# (2005, 140b) [Unknown]                           LO: 'normalized'
# (2050, 0020) Presentation LUT Shape              CS: 'IDENTITY'
# (3109, 0010) Private Creator                     LO: 'Applicare/RadWorks/Version 5.0'
# (3109, 0011) Private Creator                     LO: 'Applicare/RadWorks/Version 6.0/Summary'
# (3109, 1002) [NEW/SEEN Status]                   SH: 'NEW'
# (3109, 1008) [Receive Origin]                    LO: '192.168.210.54'
# (3109, 100a) [Receive Date]                      DA: '20150114'
# (3109, 100b) [Receive Time]                      TM: '135015'
# (3109, 1112) [Receive Origin Description]        ST: 'RJNDAS54'
# (7fd1, 0000) Private Creator                     UL: 26
# (7fd1, 0010) Private tag data                    LO: 'GEIIS'
# (7fd1, 1010) [GE IIS Compression ID]             UL: 0
# (7fe0, 0000) Group Length                        UL: 131084
# (7fe0, 0010) Pixel Data                          OW: Array of 131072 elements

# %% [markdown]
# To see if dicom data is in right order we can use "SliceLocation" attribute.

# %%
for slice in mri_datas[:5]:
    print(slice.SliceLocation) # slice location is telling us the relative location of the slices recording to coordinate system.
    # it can be obtain from dicom files. You can find it at (0020, 1041) at every dicom files. To be sorted this slice locations should be
    # in ascending order. First slice should have slice location of 0, second should be more than 0 and so on.
    
# They are in right order because we ordered the files before fetching the file contents in all_files array.
# Out:
# 0.0
# 5.99999663091323
# 11.9999973042441
# 17.9999979772582
# 23.9999946081714

# %% [markdown]
# Now we extract the actual data (pixel_arrays) from the Dicom files and store them in a list

# %%
full_volume = []

for slices in mri_datas:
    full_volume.append(slices.pixel_array)

# %% [markdown]
# And now we can take a look at some slices of the ordered 3D volume:

# %%
fig, axis = plt.subplots(6, 5, figsize = (20, 20))

slice_counter = 0
for i in range(0,6):
    for j in range(0,5):
        if (slice_counter < 27):
            axis[i][j].imshow(full_volume[ slice_counter], cmap = "gray")
            slice_counter = slice_counter + 1;
        else:
            plt.delaxes(axis[i,j])

# %%
# !pip install SimpleITK
# Out:
# Collecting SimpleITK
#   Downloading SimpleITK-2.2.1-cp310-cp310-win_amd64.whl (27.0 MB)
#      -------------------------------------- 27.0/27.0 MB 177.9 kB/s eta 0:00:00
# Installing collected packages: SimpleITK
# Successfully installed SimpleITK-2.2.1

# %%
import SimpleITK as sitk

# %%
series_ids = sitk.ImageSeriesReader.GetGDCMSeriesIDs(str(path_to_head_mri))
series_ids
# Out:
# ('1.3.46.670589.11.0.0.11.4.2.0.12098.5.4500.2015011413262801702',)

# %%
series_file_names = sitk.ImageSeriesReader.GetGDCMSeriesFileNames(str(path_to_head_mri), *series_ids)
series_file_names
# Out:
# ('SE000001\\MR000000',
#  'SE000001\\MR000001',
#  'SE000001\\MR000002',
#  'SE000001\\MR000003',
#  'SE000001\\MR000004',
#  'SE000001\\MR000005',
#  'SE000001\\MR000006',
#  'SE000001\\MR000007',
#  'SE000001\\MR000008',
#  'SE000001\\MR000009',
#  'SE000001\\MR000010',
#  'SE000001\\MR000011',
#  'SE000001\\MR000012',
#  'SE000001\\MR000013',
#  'SE000001\\MR000014',
#  'SE000001\\MR000015',
#  'SE000001\\MR000016',
#  'SE000001\\MR000017',
#  'SE000001\\MR000018',
#  'SE000001\\MR000019',
#  'SE000001\\MR000020',
#  'SE000001\\MR000021',
#  'SE000001\\MR000022',
#  'SE000001\\MR000023',
#  'SE000001\\MR000024',
#  'SE000001\\MR000025',
#  'SE000001\\MR000026')

# %%
series_reader = sitk.ImageSeriesReader()
series_reader.SetFileNames(series_file_names)

# %%
image_data = series_reader.Execute()

# %%
head_mri = sitk.GetArrayFromImage(image_data)

# %%
head_mri.shape
# Out:
# (27, 256, 256)

# %%
fig, axis = plt.subplots(6, 5, figsize = (20, 20))

slice_counter = 0
for i in range(0,6):
    for j in range(0,5):
        if (slice_counter < 27):
            axis[i][j].imshow(head_mri[ slice_counter], cmap = "bone")
            slice_counter = slice_counter + 1;
        else:
            plt.delaxes(axis[i,j])
